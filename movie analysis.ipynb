# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

plt.style.use('fivethirtyeight')

plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['text.color'] = 'k'

# %%
df = pd.read_csv('movies.csv/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ### Checking for missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
is_null = df.isnull().sum()

# %%
is_null[is_null > 0]
# Out:
# rating        77
# released       2
# score          3
# votes          3
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
is_null_m = df.isnull().mean()

# %%
is_null_m[is_null_m > 0]
# Out:
# rating      0.010042
# released    0.000261
# score       0.000391
# votes       0.000391
# writer      0.000391
# star        0.000130
# country     0.000391
# budget      0.283125
# gross       0.024648
# company     0.002217
# runtime     0.000522
# dtype: float64

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# Quieres quitarle a esta columna el .0
#
# Pero te esta dando error porque tienes missing values
#
# Tienes que decidir que hacer con ellos

# %%
df['budget'] = df['budget'].fillna(0)

# %%
df[df['budget'] == 0].head(2)
# Out:
#           name rating   genre  year                           released  score  \
# 16        Fame      R   Drama  1980       May 16, 1980 (United States)    6.6
# 19  Stir Crazy      R  Comedy  1980  December 12, 1980 (United States)    6.8
#
#       votes        director              writer         star        country  \
# 16  21000.0     Alan Parker    Christopher Gore  Eddie Barth  United States
# 19  26000.0  Sidney Poitier  Bruce Jay Friedman  Gene Wilder  United States
#
#     budget        gross                    company  runtime
# 16     0.0   21202829.0  Metro-Goldwyn-Mayer (MGM)    134.0
# 19     0.0  101300000.0          Columbia Pictures    111.0

# %%
df['budget'] = df['budget'].astype('int64')

# %%
df['gross'] = df['gross'].fillna(0)

# %%
df['gross'] = df['gross'].astype('int64')

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [markdown]
# #### cheking data types

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# #### Taking the year from release column
#
# Now we are going to take the year from the release column by using datetime.
#
# But firts it is necesary to change the realesed column from string to datetime

# %%
df['released'] = pd.to_datetime(df['released'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-30-86ab599dba12> in <module>
# ----> 1 pd.to_datetime(df['released'])
#
# ...

# %%
df['released'].value_counts()
# Out:
# May 17, 2019 (United States)           9
# February 14, 1986 (United States)      9
# October 4, 1991 (United States)        9
# August 9, 2019 (United States)         8
# November 6, 1987 (United States)       8
#                                       ..
# January 1, 1999 (United Kingdom)       1
# September 13, 2013 (United Kingdom)    1
# April 11, 1997 (Brazil)                1
# December 1, 2016 (United States)       1
# May 24, 2002 (France)                  1
# Name: released, Length: 3414, dtype: int64

# %% [markdown]
# Tienes que quitarle el extra del país
